# %%
import os

# %%
# %pwd
# Out:
# '/Users/manideep/PycharmProjects/PythonProject/End to End Chicken Disease Classification'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# '/Users/manideep/PycharmProjects/PythonProject'

# %%
os.chdir("/Users/manideep/PycharmProjects/PythonProject/End to End Chicken Disease Classification")

# %%
# %pwd
# Out:
# '/Users/manideep/PycharmProjects/PythonProject/End to End Chicken Disease Classification'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class PrepareCallbacksConfig:
    root_dir: Path
    tensorboard_root_log_dir: Path
    checkpoint_model_filepath: Path

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])



    def get_prepare_callback_config(self) -> PrepareCallbacksConfig:
        config = self.config.prepare_callbacks
        model_ckpt_dir = os.path.dirname(config.checkpoint_model_filepath)
        create_directories([
            Path(model_ckpt_dir),
            Path(config.tensorboard_root_log_dir)
        ])

        prepare_callback_config = PrepareCallbacksConfig(
            root_dir=Path(config.root_dir),
            tensorboard_root_log_dir=Path(config.tensorboard_root_log_dir),
            checkpoint_model_filepath=Path(config.checkpoint_model_filepath)
        )

        return prepare_callback_config

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf
import time

# %%
class PrepareCallback:
    def __init__(self, config: PrepareCallbacksConfig):
        self.config = config


    @property
    def _create_tb_callbacks(self):
        timestamp = time.strftime("%Y-%m-%d-%H-%M-%S")
        tb_running_log_dir = os.path.join(
            self.config.tensorboard_root_log_dir,
            f"tb_logs_at_{timestamp}",
        )
        return tf.keras.callbacks.TensorBoard(log_dir=tb_running_log_dir)


    @property
    def _create_ckpt_callbacks(self):
        return tf.keras.callbacks.ModelCheckpoint(
            filepath=self.config.checkpoint_model_filepath,
            save_best_only=True
        )


    def get_tb_ckpt_callbacks(self):
        return [
            self._create_tb_callbacks,
            self._create_ckpt_callbacks
        ]

# %%
try:
    config = ConfigurationManager()
    prepare_callbacks_config = config.get_prepare_callback_config()
    prepare_callbacks = PrepareCallback(config=prepare_callbacks_config)
    callback_list = prepare_callbacks.get_tb_ckpt_callbacks()

except Exception as e:
    raise e
# Out:
# [2025-12-23 01:15:00,371: INFO: common: yaml file: config/config.yaml loaded successfully]
# [2025-12-23 01:15:00,372: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-12-23 01:15:00,373: INFO: common: created directory at: artifacts]
# [2025-12-23 01:15:00,373: INFO: common: created directory at: artifacts/prepare_callbacks/checkpoint_dir]
# [2025-12-23 01:15:00,374: INFO: common: created directory at: artifacts/prepare_callbacks/tensorboard_log_dir]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 8
#       5     callback_list = prepare_callbacks.get_tb_ckpt_callbacks()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[57], line 5
#       3     prepare_callbacks_config = config.get_prepare_callback_config()
#       4     prepare_callbacks = PrepareCallback(config=prepare_callbacks_config)
# ----> 5     callback_list = prepare_callbacks.get_tb_ckpt_callbacks()
#       7 except Exception as e:
#       8     raise e
#
# Cell In[56], line 27, in PrepareCallback.get_tb_ckpt_callbacks(self)
#      24 def get_tb_ckpt_callbacks(self):
#      25     return [
#      26         self._create_tb_callbacks,
# ---> 27         self._create_ckpt_callbacks
#      28     ]
#
# Cell In[56], line 18, in PrepareCallback._create_ckpt_callbacks(self)
#      16 @property
#      17 def _create_ckpt_callbacks(self):
# ---> 18     return tf.keras.callbacks.ModelCheckpoint(
#      19         filepath=self.config.checkpoint_model_filepath,
#      20         save_best_only=True
#      21     )
#
# File ~/PycharmProjects/PythonProject/End to End Chicken Disease Classification/.venv/lib/python3.8/site-packages/keras/src/callbacks.py:1369, in ModelCheckpoint.__init__(self, filepath, monitor, verbose, save_best_only, save_weights_only, mode, save_freq, options, initial_value_threshold, **kwargs)
#    1363         raise TypeError(
#    1364             "If save_weights_only is True, then `options` must be "
#    1365             "either None or a tf.train.CheckpointOptions. "
#    1366             f"Got {options}."
#    1367         )
#    1368 else:
# -> 1369     if filepath and filepath.endswith(".keras") and options is not None:
#    1370         raise ValueError(
#    1371             "The native Keras format does not support "
#    1372             "the `options` argument. Please remove "
#    (...)
#    1375             "the model filepath."
#    1376         )
#    1377     if options is None or isinstance(
#    1378         options, tf.saved_model.SaveOptions
#    1379     ):
#
# AttributeError: 'PosixPath' object has no attribute 'endswith'
